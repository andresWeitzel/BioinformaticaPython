# %%
from itertools import combinations



sec="LIAGLAANFLPQILCKIARKC"



print("Secuencia Original : ", sec)

print("\n")

aminoacidos= ["A","G","U"]

i=0

for amino in aminoacidos:

    sec = sec.replace("C",aminoacidos[i])
    
    print(sec)
    
    
    combSec = combinations(sec, 2)
    
    for comb in combSec:
        print(comb)
    
    
    sec="LIAGLAANFLPQILCKIARKC"

    i=i+1
# Out:
# Secuencia Original :  LIAGLAANFLPQILCKIARKC
#
#
# LIAGLAANFLPQILAKIARKA
# ('L', 'I')
# ('L', 'A')
# ('L', 'G')
# ('L', 'L')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'A')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'A')
# ('I', 'A')
# ('I', 'G')
# ('I', 'L')
# ('I', 'A')
# ('I', 'A')
# ('I', 'N')
# ('I', 'F')
# ('I', 'L')
# ('I', 'P')
# ('I', 'Q')
# ('I', 'I')
# ('I', 'L')
# ('I', 'A')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'A')
# ('A', 'G')
# ('A', 'L')
# ('A', 'A')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'A')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'A')
# ('G', 'L')
# ('G', 'A')
# ('G', 'A')
# ('G', 'N')
# ('G', 'F')
# ('G', 'L')
# ('G', 'P')
# ('G', 'Q')
# ('G', 'I')
# ('G', 'L')
# ('G', 'A')
# ('G', 'K')
# ('G', 'I')
# ('G', 'A')
# ('G', 'R')
# ('G', 'K')
# ('G', 'A')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'A')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'A')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'A')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'A')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'A')
# ('N', 'F')
# ('N', 'L')
# ('N', 'P')
# ('N', 'Q')
# ('N', 'I')
# ('N', 'L')
# ('N', 'A')
# ('N', 'K')
# ('N', 'I')
# ('N', 'A')
# ('N', 'R')
# ('N', 'K')
# ('N', 'A')
# ('F', 'L')
# ('F', 'P')
# ('F', 'Q')
# ('F', 'I')
# ('F', 'L')
# ('F', 'A')
# ('F', 'K')
# ('F', 'I')
# ('F', 'A')
# ('F', 'R')
# ('F', 'K')
# ('F', 'A')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'A')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'A')
# ('P', 'Q')
# ('P', 'I')
# ('P', 'L')
# ('P', 'A')
# ('P', 'K')
# ('P', 'I')
# ('P', 'A')
# ('P', 'R')
# ('P', 'K')
# ('P', 'A')
# ('Q', 'I')
# ('Q', 'L')
# ('Q', 'A')
# ('Q', 'K')
# ('Q', 'I')
# ('Q', 'A')
# ('Q', 'R')
# ('Q', 'K')
# ('Q', 'A')
# ('I', 'L')
# ('I', 'A')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'A')
# ('L', 'A')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'A')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'A')
# ('K', 'I')
# ('K', 'A')
# ('K', 'R')
# ('K', 'K')
# ('K', 'A')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'A')
# ('R', 'K')
# ('R', 'A')
# ('K', 'A')
# LIAGLAANFLPQILGKIARKG
# ('L', 'I')
# ('L', 'A')
# ('L', 'G')
# ('L', 'L')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'G')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'G')
# ('I', 'A')
# ('I', 'G')
# ('I', 'L')
# ('I', 'A')
# ('I', 'A')
# ('I', 'N')
# ('I', 'F')
# ('I', 'L')
# ('I', 'P')
# ('I', 'Q')
# ('I', 'I')
# ('I', 'L')
# ('I', 'G')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'G')
# ('A', 'G')
# ('A', 'L')
# ('A', 'A')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'G')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'G')
# ('G', 'L')
# ('G', 'A')
# ('G', 'A')
# ('G', 'N')
# ('G', 'F')
# ('G', 'L')
# ('G', 'P')
# ('G', 'Q')
# ('G', 'I')
# ('G', 'L')
# ('G', 'G')
# ('G', 'K')
# ('G', 'I')
# ('G', 'A')
# ('G', 'R')
# ('G', 'K')
# ('G', 'G')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'G')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'G')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'G')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'G')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'G')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'G')
# ('N', 'F')
# ('N', 'L')
# ('N', 'P')
# ('N', 'Q')
# ('N', 'I')
# ('N', 'L')
# ('N', 'G')
# ('N', 'K')
# ('N', 'I')
# ('N', 'A')
# ('N', 'R')
# ('N', 'K')
# ('N', 'G')
# ('F', 'L')
# ('F', 'P')
# ('F', 'Q')
# ('F', 'I')
# ('F', 'L')
# ('F', 'G')
# ('F', 'K')
# ('F', 'I')
# ('F', 'A')
# ('F', 'R')
# ('F', 'K')
# ('F', 'G')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'G')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'G')
# ('P', 'Q')
# ('P', 'I')
# ('P', 'L')
# ('P', 'G')
# ('P', 'K')
# ('P', 'I')
# ('P', 'A')
# ('P', 'R')
# ('P', 'K')
# ('P', 'G')
# ('Q', 'I')
# ('Q', 'L')
# ('Q', 'G')
# ('Q', 'K')
# ('Q', 'I')
# ('Q', 'A')
# ('Q', 'R')
# ('Q', 'K')
# ('Q', 'G')
# ('I', 'L')
# ('I', 'G')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'G')
# ('L', 'G')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'G')
# ('G', 'K')
# ('G', 'I')
# ('G', 'A')
# ('G', 'R')
# ('G', 'K')
# ('G', 'G')
# ('K', 'I')
# ('K', 'A')
# ('K', 'R')
# ('K', 'K')
# ('K', 'G')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'G')
# ('A', 'R')
# ('A', 'K')
# ('A', 'G')
# ('R', 'K')
# ('R', 'G')
# ('K', 'G')
# LIAGLAANFLPQILUKIARKU
# ('L', 'I')
# ('L', 'A')
# ('L', 'G')
# ('L', 'L')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'U')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'U')
# ('I', 'A')
# ('I', 'G')
# ('I', 'L')
# ('I', 'A')
# ('I', 'A')
# ('I', 'N')
# ('I', 'F')
# ('I', 'L')
# ('I', 'P')
# ('I', 'Q')
# ('I', 'I')
# ('I', 'L')
# ('I', 'U')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'U')
# ('A', 'G')
# ('A', 'L')
# ('A', 'A')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'U')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'U')
# ('G', 'L')
# ('G', 'A')
# ('G', 'A')
# ('G', 'N')
# ('G', 'F')
# ('G', 'L')
# ('G', 'P')
# ('G', 'Q')
# ('G', 'I')
# ('G', 'L')
# ('G', 'U')
# ('G', 'K')
# ('G', 'I')
# ('G', 'A')
# ('G', 'R')
# ('G', 'K')
# ('G', 'U')
# ('L', 'A')
# ('L', 'A')
# ('L', 'N')
# ('L', 'F')
# ('L', 'L')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'U')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'U')
# ('A', 'A')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'U')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'U')
# ('A', 'N')
# ('A', 'F')
# ('A', 'L')
# ('A', 'P')
# ('A', 'Q')
# ('A', 'I')
# ('A', 'L')
# ('A', 'U')
# ('A', 'K')
# ('A', 'I')
# ('A', 'A')
# ('A', 'R')
# ('A', 'K')
# ('A', 'U')
# ('N', 'F')
# ('N', 'L')
# ('N', 'P')
# ('N', 'Q')
# ('N', 'I')
# ('N', 'L')
# ('N', 'U')
# ('N', 'K')
# ('N', 'I')
# ('N', 'A')
# ('N', 'R')
# ('N', 'K')
# ('N', 'U')
# ('F', 'L')
# ('F', 'P')
# ('F', 'Q')
# ('F', 'I')
# ('F', 'L')
# ('F', 'U')
# ('F', 'K')
# ('F', 'I')
# ('F', 'A')
# ('F', 'R')
# ('F', 'K')
# ('F', 'U')
# ('L', 'P')
# ('L', 'Q')
# ('L', 'I')
# ('L', 'L')
# ('L', 'U')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'U')
# ('P', 'Q')
# ('P', 'I')
# ('P', 'L')
# ('P', 'U')
# ('P', 'K')
# ('P', 'I')
# ('P', 'A')
# ('P', 'R')
# ('P', 'K')
# ('P', 'U')
# ('Q', 'I')
# ('Q', 'L')
# ('Q', 'U')
# ('Q', 'K')
# ('Q', 'I')
# ('Q', 'A')
# ('Q', 'R')
# ('Q', 'K')
# ('Q', 'U')
# ('I', 'L')
# ('I', 'U')
# ('I', 'K')
# ('I', 'I')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'U')
# ('L', 'U')
# ('L', 'K')
# ('L', 'I')
# ('L', 'A')
# ('L', 'R')
# ('L', 'K')
# ('L', 'U')
# ('U', 'K')
# ('U', 'I')
# ('U', 'A')
# ('U', 'R')
# ('U', 'K')
# ('U', 'U')
# ('K', 'I')
# ('K', 'A')
# ('K', 'R')
# ('K', 'K')
# ('K', 'U')
# ('I', 'A')
# ('I', 'R')
# ('I', 'K')
# ('I', 'U')
# ('A', 'R')
# ('A', 'K')
# ('A', 'U')
# ('R', 'K')
# ('R', 'U')
# ('K', 'U')
